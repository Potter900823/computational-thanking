# %% [markdown]
# <a href="https://colab.research.google.com/github/Potter900823/computation-thanking/blob/master/week3_A108260087_%E5%90%B3%E5%B0%9A%E8%AC%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("大家好")
# Out:
# 大家好

# %%
print("楊文傑")
# Out:
# 楊文傑

# %%
print("周睿承")
# Out:
# 周睿承

# %%
print("蔡嘉祐")
# Out:
# 蔡嘉祐

# %%
print("李胤澄")
# Out:
# 李胤澄

# %%
print("丁柏元")
# Out:
# 丁柏元
